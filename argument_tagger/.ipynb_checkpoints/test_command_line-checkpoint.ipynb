# %%
run main_retrieval.py topics-task-2.xml 50 15 False False False
# Out:
# [[{'label': 'O', 'prob': '0.8075389', 'token': 'Difference'}, {'label': 'O', 'prob': '0.8940402', 'token': 'Between'}, {'label': 'O', 'prob': '0.9288932', 'token': 'Love'}, {'label': 'O', 'prob': '0.9473025', 'token': 'And'}, {'label': 'O', 'prob': '0.9392401', 'token': 'Sex'}, {'label': 'O', 'prob': '0.95343184', 'token': '-'}, {'label': 'O', 'prob': '0.9672346', 'token': 'Student.com'}, {'label': 'O', 'prob': '0.9582832', 'token': 'Articles'}, {'label': 'O', 'prob': '0.9458477', 'token': '.'}], [{'label': 'P-I', 'prob': '0.29349795', 'token': 'Sex'}, {'label': 'P-I', 'prob': '0.39054233', 'token': 'may'}, {'label': 'P-I', 'prob': '0.39955023', 'token': 'or'}, {'label': 'P-I', 'prob': '0.36923197', 'token': 'may'}, {'label': 'P-I', 'prob': '0.36106956', 'token': 'not'}, {'label': 'P-I', 'prob': '0.3583028', 'token': 'include'}, {'label': 'P-I', 'prob': '0.41179004', 'token': 'penetration'}, {'label': 'P-I', 'prob': '0.4163426', 'token': '.'}], [{'label': 'B-I', 'prob': '0.41745287', 'token': 'Differences'}, {'label': 'B-I', 'prob': '0.65472156', 'token': 'Between'}, {'label': 'B-I', 'prob': '0.73175263', 'token': 'Love'}, {'label': 'B-I', 'prob': '0.7020551', 'token': 'and'}, {'label': 'B-I', 'prob': '0.7015561', 'token': 'Sex'}, {'label': 'B-I', 'prob': '0.7427721', 'token': 'Love'}, {'label': 'B-I', 'prob': '0.7351619', 'token': 'Love'}, {'label': 'B-I', 'prob': '0.68275195', 'token': 'is'}, {'label': 'B-I', 'prob': '0.6897782', 'token': 'a'}, {'label': 'B-I', 'prob': '0.67623067', 'token': 'feeling'}, {'label': 'B-I', 'prob': '0.6821979', 'token': '('}, {'label': 'B-I', 'prob': '0.6590728', 'token': 'emotional'}, {'label': 'B-I', 'prob': '0.65043443', 'token': ')'}, {'label': 'B-I', 'prob': '0.6214586', 'token': '.'}], [{'label': 'O', 'prob': '0.7124322', 'token': 'There'}, {'label': 'O', 'prob': '0.7880212', 'token': 'is'}, {'label': 'O', 'prob': '0.72243494', 'token': 'no'}, {'label': 'O', 'prob': '0.7038527', 'token': 'exact'}, {'label': 'O', 'prob': '0.6603936', 'token': '&'}, {'label': 'O', 'prob': '0.6774842', 'token': 'quot'}, {'label': 'O', 'prob': '0.6688151', 'token': ';'}, {'label': 'O', 'prob': '0.66255575', 'token': 'right'}, {'label': 'O', 'prob': '0.6454401', 'token': '&'}, {'label': 'O', 'prob': '0.6803855', 'token': 'quot'}, {'label': 'O', 'prob': '0.6832523', 'token': ';'}, {'label': 'O', 'prob': '0.68975747', 'token': 'definition'}, {'label': 'O', 'prob': '0.6915625', 'token': 'of'}, {'label': 'O', 'prob': '0.70108896', 'token': 'love'}, {'label': 'O', 'prob': '0.70657027', 'token': 'for'}, {'label': 'O', 'prob': '0.7102836', 'token': 'everybody'}, {'label': 'O', 'prob': '0.6599298', 'token': '.'}], [{'label': 'O', 'prob': '0.66866505', 'token': 'Love'}, {'label': 'O', 'prob': '0.7463279', 'token': 'involves'}, {'label': 'O', 'prob': '0.7088308', 'token': 'feelings'}, {'label': 'O', 'prob': '0.7360503', 'token': 'of'}, {'label': 'O', 'prob': '0.72760063', 'token': 'romance'}, {'label': 'O', 'prob': '0.74084795', 'token': 'and'}, {'label': 'O', 'prob': '0.7302871', 'token': '&'}, {'label': 'O', 'prob': '0.76423097', 'token': '#'}, {'label': 'O', 'prob': '0.80307525', 'token': 'x2F'}, {'label': 'O', 'prob': '0.77472234', 'token': ';'}, {'label': 'O', 'prob': '0.75794464', 'token': 'or'}, {'label': 'O', 'prob': '0.7472532', 'token': 'attraction'}, {'label': 'O', 'prob': '0.7607143', 'token': '.'}], [{'label': 'O', 'prob': '0.5189605', 'token': 'Sex'}, {'label': 'O', 'prob': '0.6285204', 'token': ':'}, {'label': 'O', 'prob': '0.53724056', 'token': 'Sex'}, {'label': 'O', 'prob': '0.5492331', 'token': 'is'}, {'label': 'O', 'prob': '0.55992895', 'token': 'an'}, {'label': 'O', 'prob': '0.57786286', 'token': 'event'}, {'label': 'O', 'prob': '0.5823392', 'token': 'or'}, {'label': 'O', 'prob': '0.5615512', 'token': 'act'}]]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
# ---> 38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://demo.webis.de/targer-api/%3Cfunction%20targer%20at%200x7fe8f1e12560%3E
#
# During handling of the above exception, another exception occurred:
#
# ...
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      40         except requests.exceptions.HTTPError:
#      41             time.sleep(1)
# ---> 42             return targer()
#      43     response = targer()
#      44     print(response)
#
# ~/Downloads/0_Studium/0_AIR_Vorlesung/air_comparative_arguments_machine/argument_tagger/argument_score_2.py in targer()
#      35     def targer():
#      36         try:
# ---> 37             response = requests.request("POST", url, headers=headers, data=payload.encode('utf-8'))
#      38             response.raise_for_status()
#      39             return response.json()
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     374         # Trigger any extra validation we need to do.
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#     378             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     992         # Force connect early to allow us to validate the connection.
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#     996         if not conn.is_verified:
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     392             ca_cert_dir=self.ca_cert_dir,
#     393             server_hostname=server_hostname,
# --> 394             ssl_context=context,
#     395         )
#     396
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password)
#     368     ) or IS_SECURETRANSPORT:
#     369         if HAS_SNI and server_hostname is not None:
# --> 370             return context.wrap_socket(sock, server_hostname=server_hostname)
#     371
#     372         warnings.warn(
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     483         while True:
#     484             try:
# --> 485                 cnx.do_handshake()
#     486             except OpenSSL.SSL.WantReadError:
#     487                 if not util.wait_for_read(sock, sock.gettimeout()):
#
# ~/anaconda3/envs/internetsuchmaschine/lib/python3.7/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1912         :return: None.
#    1913         """
# -> 1914         result = _lib.SSL_do_handshake(self._ssl)
#    1915         self._raise_ssl_error(self._ssl, result)
#    1916
#
# KeyboardInterrupt:

# %%
from itertools import chain
list(chain.from_iterable([[180,0], [173,8], [164,2], [156,5], [147,2], [138,2]]))
# Out:
# [180, 0, 173, 8, 164, 2, 156, 5, 147, 2, 138, 2]

# %%
400 error
